# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df = pd.read_csv("HousingData.csv")
df.head(10)
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM    AGE     DIS  RAD  TAX  PTRATIO  \
# 0  0.00632  18.0   2.31   0.0  0.538  6.575   65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07   0.0  0.469  6.421   78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07   0.0  0.469  7.185   61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18   0.0  0.458  6.998   45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18   0.0  0.458  7.147   54.2  6.0622    3  222     18.7
# 5  0.02985   0.0   2.18   0.0  0.458  6.430   58.7  6.0622    3  222     18.7
# 6  0.08829  12.5   7.87   NaN  0.524  6.012   66.6  5.5605    5  311     15.2
# 7  0.14455  12.5   7.87   0.0  0.524  6.172   96.1  5.9505    5  311     15.2
# 8  0.21124  12.5   7.87   0.0  0.524  5.631  100.0  6.0821    5  311     15.2
# 9  0.17004  12.5   7.87   NaN  0.524  6.004   85.9  6.5921    5  311     15.2
#
#         B  LSTAT  MEDV
# 0  396.90   4.98  24.0
# 1  396.90   9.14  21.6
# 2  392.83   4.03  34.7
# ...

# %%
df.columns
# Out:
# Index(['CRIM', 'ZN', 'INDUS', 'CHAS', 'NOX', 'RM', 'AGE', 'DIS', 'RAD', 'TAX',
#        'PTRATIO', 'B', 'LSTAT', 'MEDV'],
#       dtype='object')

# %%
df['price'] = df['MEDV']

# %%
df.drop("MEDV", axis=1)
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  \
# 0    0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900    1  296
# 1    0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671    2  242
# 2    0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671    2  242
# 3    0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622    3  222
# 4    0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622    3  222
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...  ...
# 501  0.06263   0.0  11.93   0.0  0.573  6.593  69.1  2.4786    1  273
# 502  0.04527   0.0  11.93   0.0  0.573  6.120  76.7  2.2875    1  273
# 503  0.06076   0.0  11.93   0.0  0.573  6.976  91.0  2.1675    1  273
# 504  0.10959   0.0  11.93   0.0  0.573  6.794  89.3  2.3889    1  273
# 505  0.04741   0.0  11.93   0.0  0.573  6.030   NaN  2.5050    1  273
#
#      PTRATIO       B  LSTAT  price
# 0       15.3  396.90   4.98   24.0
# 1       17.8  396.90   9.14   21.6
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 15 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   CRIM     486 non-null    float64
#  1   ZN       486 non-null    float64
#  2   INDUS    486 non-null    float64
#  3   CHAS     486 non-null    float64
#  4   NOX      506 non-null    float64
#  5   RM       506 non-null    float64
#  6   AGE      486 non-null    float64
#  7   DIS      506 non-null    float64
#  8   RAD      506 non-null    int64
#  9   TAX      506 non-null    int64
#  10  PTRATIO  506 non-null    float64
#  11  B        506 non-null    float64
#  12  LSTAT    486 non-null    float64
#  13  MEDV     506 non-null    float64
#  14  price    506 non-null    float64
# dtypes: float64(13), int64(2)
# memory usage: 59.4 KB

# %%
df.describe()
# Out:
#              CRIM          ZN       INDUS        CHAS         NOX          RM  \
# count  486.000000  486.000000  486.000000  486.000000  506.000000  506.000000
# mean     3.611874   11.211934   11.083992    0.069959    0.554695    6.284634
# std      8.720192   23.388876    6.835896    0.255340    0.115878    0.702617
# min      0.006320    0.000000    0.460000    0.000000    0.385000    3.561000
# 25%      0.081900    0.000000    5.190000    0.000000    0.449000    5.885500
# 50%      0.253715    0.000000    9.690000    0.000000    0.538000    6.208500
# 75%      3.560263   12.500000   18.100000    0.000000    0.624000    6.623500
# max     88.976200  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               AGE         DIS         RAD         TAX     PTRATIO           B  \
# count  486.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    68.518519    3.795043    9.549407  408.237154   18.455534  356.674032
# ...

# %%
df.isnull().sum()
# Out:
# CRIM       20
# ZN         20
# INDUS      20
# CHAS       20
# NOX         0
# RM          0
# AGE        20
# DIS         0
# RAD         0
# TAX         0
# PTRATIO     0
# B           0
# LSTAT      20
# MEDV        0
# price       0
# dtype: int64

# %%
df["CRIM"] = df["CRIM"].fillna(df["CRIM"].median())
df["ZN"] = df["ZN"].fillna(df["ZN"].median())
df["INDUS"] = df["INDUS"].fillna(df["INDUS"].median())
df["CHAS"] = df["CHAS"].fillna(df["CHAS"].median())
df["AGE"] = df["AGE"].fillna(df["AGE"].median())
df["LSTAT"] = df["LSTAT"].fillna(df["LSTAT"].median())

# %%
df.isnull().sum()
# Out:
# CRIM       0
# ZN         0
# INDUS      0
# CHAS       0
# NOX        0
# RM         0
# AGE        0
# DIS        0
# RAD        0
# TAX        0
# PTRATIO    0
# B          0
# LSTAT      0
# MEDV       0
# price      0
# dtype: int64

# %%
df.corr()
# Out:
#              CRIM        ZN     INDUS      CHAS       NOX        RM       AGE  \
# CRIM     1.000000 -0.185359  0.392632 -0.055585  0.410971 -0.220045  0.343427
# ZN      -0.185359  1.000000 -0.507304 -0.032992 -0.498619  0.312295 -0.535341
# INDUS    0.392632 -0.507304  1.000000  0.054693  0.738387 -0.377978  0.614248
# CHAS    -0.055585 -0.032992  0.054693  1.000000  0.070867  0.106797  0.074984
# NOX      0.410971 -0.498619  0.738387  0.070867  1.000000 -0.302188  0.711864
# RM      -0.220045  0.312295 -0.377978  0.106797 -0.302188  1.000000 -0.239518
# AGE      0.343427 -0.535341  0.614248  0.074984  0.711864 -0.239518  1.000000
# DIS     -0.366025  0.632428 -0.698621 -0.092318 -0.769230  0.205246 -0.724354
# RAD      0.601224 -0.300061  0.592735 -0.003339  0.611441 -0.209847  0.447088
# TAX      0.560469 -0.304385  0.716267 -0.035822  0.668023 -0.292048  0.498408
# PTRATIO  0.277964 -0.394622  0.385366 -0.109451  0.188933 -0.355501  0.261826
# ...

# %%
sns.pairplot(df)

# %%
plt.scatter(df['CRIM'],df['price'])
plt.show()

# %%
plt.scatter(df['CRIM'],df['price'])
plt.show()

# %%
plt.scatter(df['RM'],df['price'])
plt.show()

# %%
# negative corr
sns.regplot(x="INDUS",y="price",data = df)
plt.show()

# %%
#strong negative
sns.regplot(x="LSTAT",y="price",data = df)
plt.show()

# %%
sns.regplot(x="CHAS",y="price",data = df)
plt.show()

# %%
sns.regplot(x="PTRATIO",y="price",data = df)
plt.show()

# %%
X = df.drop("price", axis=1)   # Independent features
Y = df["price"]

# %%
X.shape
# Out:
# (506, 14)

# %%
Y.shape
# Out:
# (506,)

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(X,Y, test_size=0.3,random_state=42)

# %%
x_train.shape
# Out:
# (354, 14)

# %%
y_train.shape
# Out:
# (354,)

# %%
x_test.shape
# Out:
# (152, 14)

# %%
y_test.shape
# Out:
# (152,)

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
x_train = scaler.fit_transform(x_train)
x_test = scaler.transform(x_test)

# %%
#model trainning
from sklearn.linear_model import LinearRegression
LR = LinearRegression()

# %%
LR.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
# print the coefficient’s  and  intercept 
print(LR.coef_)
# Out:
# [ 1.30749220e-14 -1.02140518e-14  1.23234756e-14 -3.05311332e-16
#   1.70974346e-14 -9.93649607e-15  1.09912079e-14 -4.66293670e-15
#   1.08801856e-14  9.10382880e-15  1.08801856e-14 -9.21485110e-15
#   1.08801856e-14  9.37531490e+00]

# %%
print(LR.intercept_)
# Out:
# 23.01581920903955

# %%
# on which parameter the model has been trained 
LR.get_params()
# Out:
# {'copy_X': True, 'fit_intercept': True, 'n_jobs': None, 'positive': False}

# %%
#prediction on test data
y_predict = LR.predict(x_test)
y_predict
# Out:
# array([23.6, 32.4, 13.6, 22.8, 16.1, 20. , 17.8, 14. , 19.6, 16.8, 21.5,
#        18.9,  7. , 21.2, 18.5, 29.8, 18.8, 10.2, 50. , 14.1, 25.2, 29.1,
#        12.7, 22.4, 14.2, 13.8, 20.3, 14.9, 21.7, 18.3, 23.1, 23.8, 15. ,
#        20.8, 19.1, 19.4, 34.7, 19.5, 24.4, 23.4, 19.7, 28.2, 50. , 17.4,
#        22.6, 15.1, 13.1, 24.2, 19.9, 24. , 18.9, 35.4, 15.2, 26.5, 43.5,
#        21.2, 18.4, 28.5, 23.9, 18.5, 25. , 35.4, 31.5, 20.2, 24.1, 20. ,
#        13.1, 24.8, 30.8, 12.7, 20. , 23.7, 10.8, 20.6, 20.8,  5. , 20.1,
#        48.5, 10.9,  7. , 20.9, 17.2, 20.9,  9.7, 19.4, 29. , 16.4, 25. ,
#        25. , 17.1, 23.2, 10.4, 19.6, 17.2, 27.5, 23. , 50. , 17.9,  9.6,
#        17.2, 22.5, 21.4, 12. , 19.9, 19.4, 13.4, 18.2, 24.6, 21.1, 24.7,
#         8.7, 27.5, 20.7, 36.2, 31.6, 11.7, 39.8, 13.9, 21.8, 23.7, 17.6,
#        24.4,  8.8, 19.2, 25.3, 20.4, 23.1, 37.9, 15.6, 45.4, 15.7, 22.6,
#        14.5, 18.7, 17.8, 16.1, 20.6, 31.6, 29.1, 15.6, 17.5, 22.5, 19.4,
# ...

# %%
#lets plot a scatter plot for the prediction
plt.scatter(y_test,y_predict)
plt.show()

# %%
#calculating residual means error = y_test-predict
Residual = y_test - y_predict
Residual
# Out:
# 173    3.552714e-14
# 274    1.136868e-13
# 491   -9.414691e-14
# 72     6.750156e-14
# 452   -1.101341e-13
#            ...
# 441   -1.136868e-13
# 23    -3.197442e-14
# 225    9.947598e-14
# 433   -1.367795e-13
# 447   -1.278977e-13
# Name: price, Length: 152, dtype: float64

# %%
sns.displot(Residual,kind = "kde")
plt.show()

# %%
plt.scatter(y_predict,Residual)
plt.show()

# %%
from sklearn.metrics import r2_score,mean_squared_error,root_mean_squared_error,mean_absolute_error
print(r2_score(y_test,y_predict))
print(mean_squared_error(y_test,y_predict))
print(root_mean_squared_error(y_test,y_predict))
print(mean_absolute_error(y_test,y_predict))
# Out:
# 1.0
# 1.0442276359395568e-26
# 1.0218745695727812e-13
# 8.372250261489075e-14

# %%
print("price" in X.columns)
# Out:
# False

# %%
np.allclose(y_test, y_predict)
# Out:
# True

# %%
# 1. Define features and target
X = df.drop("price", axis=1)
y = df["price"]

# 2. Split
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.3, random_state=42
)

# 3. Pipeline (prevents bugs)
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LinearRegression

pipe = Pipeline([
    ("scaler", StandardScaler()),
    ("model", LinearRegression())
])

# 4. Train
pipe.fit(X_train, y_train)

# 5. Predict (THIS is critical)
y_predict = pipe.predict(X_test)

# %%
y_predict
# Out:
# array([23.6, 32.4, 13.6, 22.8, 16.1, 20. , 17.8, 14. , 19.6, 16.8, 21.5,
#        18.9,  7. , 21.2, 18.5, 29.8, 18.8, 10.2, 50. , 14.1, 25.2, 29.1,
#        12.7, 22.4, 14.2, 13.8, 20.3, 14.9, 21.7, 18.3, 23.1, 23.8, 15. ,
#        20.8, 19.1, 19.4, 34.7, 19.5, 24.4, 23.4, 19.7, 28.2, 50. , 17.4,
#        22.6, 15.1, 13.1, 24.2, 19.9, 24. , 18.9, 35.4, 15.2, 26.5, 43.5,
#        21.2, 18.4, 28.5, 23.9, 18.5, 25. , 35.4, 31.5, 20.2, 24.1, 20. ,
#        13.1, 24.8, 30.8, 12.7, 20. , 23.7, 10.8, 20.6, 20.8,  5. , 20.1,
#        48.5, 10.9,  7. , 20.9, 17.2, 20.9,  9.7, 19.4, 29. , 16.4, 25. ,
#        25. , 17.1, 23.2, 10.4, 19.6, 17.2, 27.5, 23. , 50. , 17.9,  9.6,
#        17.2, 22.5, 21.4, 12. , 19.9, 19.4, 13.4, 18.2, 24.6, 21.1, 24.7,
#         8.7, 27.5, 20.7, 36.2, 31.6, 11.7, 39.8, 13.9, 21.8, 23.7, 17.6,
#        24.4,  8.8, 19.2, 25.3, 20.4, 23.1, 37.9, 15.6, 45.4, 15.7, 22.6,
#        14.5, 18.7, 17.8, 16.1, 20.6, 31.6, 29.1, 15.6, 17.5, 22.5, 19.4,
# ...

# %%
from sklearn.metrics import r2_score,mean_squared_error,root_mean_squared_error,mean_absolute_error
print(r2_score(y_test,y_predict))
print(mean_squared_error(y_test,y_predict))
print(root_mean_squared_error(y_test,y_predict))
print(mean_absolute_error(y_test,y_predict))
# Out:
# 1.0
# 1.0442276359395568e-26
# 1.0218745695727812e-13
# 8.372250261489075e-14

# %%
import pickle
pickle.dump(LR,open('regmodel.pkl','wb'))

# %%
pickled_model = pickle.load(open('regmodel.pkl','rb'))

# %%
pickled_model.predict(scaled_data)
# Out:
# array([24.])

# %%
# First row as Series
first_row = df.iloc[0]

# First row as DataFrame
first_row_df = df.iloc[[0]]

# Preview first row
df.head(1)
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE   DIS  RAD  TAX  PTRATIO  \
# 0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.09    1  296     15.3
#
#        B  LSTAT  MEDV  price
# 0  396.9   4.98  24.0   24.0

# %%
first_row_df = df.iloc[0].values.reshape(1, -1)
first_row_df
# Out:
# array([[6.320e-03, 1.800e+01, 2.310e+00, 0.000e+00, 5.380e-01, 6.575e+00,
#         6.520e+01, 4.090e+00, 1.000e+00, 2.960e+02, 1.530e+01, 3.969e+02,
#         4.980e+00, 2.400e+01, 2.400e+01]])

# %%
scaler = StandardScaler()

# %%
# Assistant
# First, check the type of first_row_df
# If first_row_df is a numpy array, convert it to a DataFrame or use array slicing

# If you want to convert the numpy array to a DataFrame:
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler

# Option 1: If first_row_df is a numpy array and you want to convert it to DataFrame
if isinstance(first_row_df, np.ndarray):
    first_row_df = pd.DataFrame(first_row_df)
    # Now you can use iloc
    first_row_df = first_row_df.iloc[:, :14]  # Keep only the first 14 columns
    
# Option 2: If you want to keep first_row_df as numpy array, use array slicing instead
# first_row_df = first_row_df[:, :14]  # Keep only the first 14 columns if it's a numpy array

# Now fit the scaler to your training data
scaler = StandardScaler()
scaler.fit(X_train)  # This calculates the mean and std dev needed for scaling

# Transform your data with matching features
scaled_data = scaler.transform(first_row_df)

# Alternatively, you can use fit_transform in one step for your training data
# scaled_train_data = scaler.fit_transform(X_train)
# Out:
# /opt/anaconda3/lib/python3.13/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(

# %%
scaled_data
# Out:
# array([[-0.4019127 ,  0.31308058, -1.28684958, -0.27565892, -0.16513629,
#          0.34715902, -0.14294127,  0.15267164, -0.97798895, -0.66777595,
#         -1.32142483,  0.42854113, -1.07131882,  0.10497576]])
